# %%
import discord
import asyncio
import pandas as pd
import altair as alt

# %%
intents = discord.Intents.default()
intents.messages = True
intents.guilds = True

# %%
https://discord.com/api/oauth2/authorize?client_id=1213788498717315113&permissions=66560&scope=bot

# %%
TOKEN = 'MTIxMzc4ODQ5ODcxNzMxNTExMw.GW9vK6.5CSqpDqLDZxcH6hTmWoZUserPTP2yoNyvH-Y-Y'
CHANNEL_ID = 757271564977832079
THREAD_ID = 1205565888183668736
messages = []
class MyBot(discord.Client):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs, intents=intents)
        
    async def on_ready(self):
        print(f'Logged in as {self.user}')
        await self.extract_messages_from_thread(thread_id)

    async def extract_messages_from_thread(self, thread_id):
        print("Bot is ready and will now try to fetch messages from the thread.")
        thread = await self.fetch_channel(thread_id)
        if isinstance(thread, discord.Thread):
            print(f"Found the thread: {thread.name}, fetching messages...")
            async for message in thread.history(limit=None):
                print(f'{message.author}: {message.content} (at {message.created_at})')
                messages.append([message.author.name, message.content, message.created_at])
        else:
            print("Provided ID does not belong to a thread.")

# %%
bot = MyBot()

# %%
async def main():
    await bot.start(TOKEN)  # Replace 'YOUR_BOT_TOKEN' with your bot's actual token
    await bot.extract_messages_from_thread(THREAD_ID)  # Replace YOUR_THREAD_ID with the actual thread ID

asyncio.run(main())
# Out:
# [2024-03-03 11:40:36] [INFO    ] discord.client: logging in using static token
# [2024-03-03 11:40:36] [INFO    ] discord.client: logging in using static token
# [2024-03-03 11:40:37] [INFO    ] discord.gateway: Shard ID None has connected to Gateway (Session ID: 098a432e8750223093c32aefde04a588).
# [2024-03-03 11:40:37] [INFO    ] discord.gateway: Shard ID None has connected to Gateway (Session ID: 098a432e8750223093c32aefde04a588).
# Logged in as cacadata#8668
# Bot is ready and will now try to fetch messages from the thread.
# Found the thread: Caca Journal, fetching messages...
# otromono: (kalnsd yo ya dejo de usarlo 🫡 a ver si este finde saco stats de febrero, Ima hasta el 14 solo) (at 2024-03-01 15:11:33.832000+00:00)
# ima_77: 💩 (at 2024-03-01 14:42:45.724000+00:00)
# esguille: 💩 (at 2024-03-01 09:13:54.713000+00:00)
# otromono: 💩 (at 2024-03-01 07:49:17.650000+00:00)
# ima_77: 💩 (at 2024-02-29 12:59:06.504000+00:00)
# esguille: 💩 (at 2024-02-29 10:38:44.391000+00:00)
# otromono: 💩 (at 2024-02-29 07:32:14.986000+00:00)
# esguille: 💩 (at 2024-02-28 11:53:15.170000+00:00)
# ima_77: 💩 (at 2024-02-28 08:18:36.712000+00:00)
# otromono: 💩 (at 2024-02-27 14:21:02.707000+00:00)
# esguille: 💩 (at 2024-02-27 09:55:18.086000+00:00)
# ima_77: 💩 (at 2024-02-27 06:52:54.631000+00:00)
# ima_77: 💩 (at 2024-02-26 12:56:00.356000+00:00)
# ima_77: 💩 (at 2024-02-11 11:55:35.894000+00:00)
# esguille: 💩 (at 2024-02-11 11:15:38.536000+00:00)
# otromono: 💩 (at 2024-02-11 06:48:17.966000+00:00)
# ima_77: 💩 (at 2024-02-10 16:31:45.760000+00:00)
# potajito: 💩 (at 2024-02-10 09:14:18.896000+00:00)
# esguille: 💩 (at 2024-02-10 09:06:29.501000+00:00)
# esguille: Mañana voy poniendo emoji y cuando toque y punto (at 2024-02-09 20:04:41.421000+00:00)
# esguille: Yo pa llevar ls cuenta de hoy, no de esta tarde (at 2024-02-09 20:04:30.651000+00:00)
# esguille: He explicado cuando han sido jaja (at 2024-02-09 20:03:58.799000+00:00)
# deparki: O te estás muriendo o estás trolling (at 2024-02-09 19:54:35.497000+00:00)
# deparki: Mira guille no (at 2024-02-09 19:54:27.559000+00:00)
# esguille: 💩 (at 2024-02-09 18:52:56.595000+00:00)
# esguille: 💩 (at 2024-02-09 18:52:38.230000+00:00)
# esguille: 💩 (at 2024-02-09 18:52:19.315000+00:00)
# litospk: Como diría Winnie, ya me jodería xD (at 2024-02-09 18:45:53.196000+00:00)
# litospk: Ya de paso una foto de vuestro reto mientras apretais xD (at 2024-02-09 18:45:41.853000+00:00)
# esguille: 💩 (at 2024-02-09 18:45:25.521000+00:00)
# deparki: 💩 (at 2024-02-09 18:21:07.454000+00:00)
# deparki: Que lo has hecho xhdjsh (at 2024-02-09 18:03:23.548000+00:00)
# otromono:  (at 2024-02-09 17:29:45.115000+00:00)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 5
#       2     await bot.start(TOKEN)  # Replace 'YOUR_BOT_TOKEN' with your bot's actual token
#       3     await bot.extract_messages_from_thread(THREAD_ID)  # Replace YOUR_THREAD_ID with the actual thread ID
# ----> 5 asyncio.run(main())
#
# File ~/Documents/python/discord_bot/discord-env/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/Documents/python/discord_bot/discord-env/lib/python3.11/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/Documents/python/discord_bot/discord-env/lib/python3.11/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File /usr/lib/python3.11/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %%
messages[0]
# Out:
# ['otromono',
#  '(kalnsd yo ya dejo de usarlo 🫡 a ver si este finde saco stats de febrero, Ima hasta el 14 solo)',
#  datetime.datetime(2024, 3, 1, 15, 11, 33, 832000, tzinfo=datetime.timezone.utc)]

# %%
df = pd.DataFrame(messages, columns=["name", "message", "timestamp"]).query("message == '💩'")
df["date"] = pd.to_datetime(df["timestamp"].dt.date)
df["hour"] = df["timestamp"].dt.hour
df.head()
# Out:
#        name message                        timestamp       date  hour
# 1    ima_77       💩 2024-03-01 14:42:45.724000+00:00 2024-03-01    14
# 2  esguille       💩 2024-03-01 09:13:54.713000+00:00 2024-03-01     9
# 3  otromono       💩 2024-03-01 07:49:17.650000+00:00 2024-03-01     7
# 4    ima_77       💩 2024-02-29 12:59:06.504000+00:00 2024-02-29    12
# 5  esguille       💩 2024-02-29 10:38:44.391000+00:00 2024-02-29    10

# %%
alt.Chart(df).mark_circle(size=200).encode(
    x=alt.X("date:T", title= ""),
    y=alt.Y("hour:N", title="Hora"),
    color=alt.Color("name", title="")
).properties(width=1000, height=500)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    y=alt.Y('week(date):O', title = "Semana" ),
    x=alt.X('count():Q', title = "Cacas"),
    color=alt.Color("name", title="")
).properties(width=700)
# Out:
# alt.Chart(...)

# %%
df_count_per_day = df.groupby(["name", "date"]).count()
df_count_per_day.groupby("name").mean().reset_index()[["name", "message"]]
# Out:
#        name   message
# 0   deparki  1.000000
# 1  esguille  1.600000
# 2    ima_77  1.333333
# 3  otromono  1.153846
# 4  potajito  1.000000

# %%
df_count_per_day["message"]
# Out:
# name      date
# deparki   2024-02-09    1
# esguille  2024-02-09    4
#           2024-02-10    1
#           2024-02-11    1
#           2024-02-12    2
#           2024-02-14    2
#           2024-02-15    1
#           2024-02-16    2
#           2024-02-17    2
#           2024-02-18    1
#           2024-02-19    1
#           2024-02-20    1
#           2024-02-21    2
#           2024-02-22    2
#           2024-02-23    1
#           2024-02-24    3
#           2024-02-26    2
#           2024-02-27    1
#           2024-02-28    1
#           2024-02-29    1
#           2024-03-01    1
# ima_77    2024-02-10    1
#           2024-02-11    2
#           2024-02-12    2
#           2024-02-13    1
#           2024-02-14    2
#           2024-02-21    1
#           2024-02-22    2
#           2024-02-26    1
#           2024-02-27    1
#           2024-02-28    1
#           2024-02-29    1
#           2024-03-01    1
# otromono  2024-02-11    2
#           2024-02-12    1
#           2024-02-13    1
#           2024-02-16    1
#           2024-02-17    1
#           2024-02-18    1
#           2024-02-21    2
#           2024-02-22    1
#           2024-02-24    1
#           2024-02-26    1
#           2024-02-27    1
#           2024-02-29    1
#           2024-03-01    1
# potajito  2024-02-10    1
# Name: message, dtype: int64

# %%
df.head()
# Out:
#        name message                        timestamp       date
# 1    ima_77       💩 2024-03-01 14:42:45.724000+00:00 2024-03-01
# 2  esguille       💩 2024-03-01 09:13:54.713000+00:00 2024-03-01
# 3  otromono       💩 2024-03-01 07:49:17.650000+00:00 2024-03-01
# 4    ima_77       💩 2024-02-29 12:59:06.504000+00:00 2024-02-29
# 5  esguille       💩 2024-02-29 10:38:44.391000+00:00 2024-02-29

# %%
alt.Chart(df).mark_bar().encode(
    x=alt.X('hour:N', title = "Hora del Día"),
    y=alt.Y('count():Q', title = ""),
    color=alt.Color("name", title=""),
    row=alt.Row("name", title="")
).properties(width=700, height=100)
# Out:
# alt.Chart(...)

# %%
df.to_csv("caca.csv")

# %%
alt.Chart(df.query("name == 'otromono'")).mark_bar().encode(
    x=alt.X('hour:N', title = "Hora del Día"),
    y=alt.Y('count():Q', title = ""),
    color=alt.Color("name", title="")
).properties(width=700, height=200)
# Out:
# alt.Chart(...)
